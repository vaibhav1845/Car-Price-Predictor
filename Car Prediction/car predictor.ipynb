# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
car = pd.read_csv("E:\VAIBHAV\Machine Learning Project data\Car prediction\k.csv")
car.head()
# Out:
#                                      name   company  year          price  \
# 0                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 1              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 2  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 3        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2015  Ask For Price
#
#   kms_covered fuel_type
# 0      40 kms    Diesel
# 1  22,000 kms    Petrol
# 2  28,000 kms    Petrol
# 3  36,000 kms    Diesel
# 4  59,000 kms    Diesel

# %%
car.shape
# Out:
# (891, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         891 non-null    object
#  1   company      891 non-null    object
#  2   year         891 non-null    object
#  3   price        891 non-null    object
#  4   kms_covered  839 non-null    object
#  5   fuel_type    836 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car.year.unique()
# Out:
# array(['2006', '2018', '2014', '2015', '2012', '2013', '2016', '2010',
#        '2007', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %% [markdown]
# ## Quality
# - year has many non-year values
# - year object to int
# - price has Aks for price
# - price object to int
# - kms_driven has kms with int
# - kms_driven object to int
# - kms_driven has nan values
# - fuel_type has nan values
# - keep first 3 words of name

# %% [markdown]
# ## Cleaning

# %%
backup = car.copy()

# %%
car['year']
# Out:
# 0      2006
# 1      2018
# 2      2014
# 3      2014
# 4      2015
#        ...
# 886    zest
# 887    2018
# 888    2013
# 889    2014
# 890    2014
# Name: year, Length: 891, dtype: object

# %%
car['year'].str.isnumeric().sum()
# Out:
# 841

# %%
car = car[car['year'].str.isnumeric()]

# %%
car.head()
# Out:
#                                      name   company  year          price  \
# 0                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 1              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 2  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 3        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2015  Ask For Price
#
#   kms_covered fuel_type
# 0      40 kms    Diesel
# 1  22,000 kms    Petrol
# 2  28,000 kms    Petrol
# 3  36,000 kms    Diesel
# 4  59,000 kms    Diesel

# %%
car.year=car['year'].astype(int)

# %%
car = car[car['price']!= "Ask For Price"]

# %%
car.head()
# Out:
#                                      name   company  year     price  \
# 0                 Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 2  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  3,25,000
# 3        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  5,75,000
# 5                               Ford Figo      Ford  2012  1,75,000
# 6                             Hyundai Eon   Hyundai  2013  1,90,000
#
#   kms_covered fuel_type
# 0      40 kms    Diesel
# 2  28,000 kms    Petrol
# 3  36,000 kms    Diesel
# 5  41,000 kms    Diesel
# 6  25,000 kms    Petrol

# %%
car.price= car['price'].str.replace(',','').astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 818 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         818 non-null    object
#  1   company      818 non-null    object
#  2   year         818 non-null    int32
#  3   price        818 non-null    int32
#  4   kms_covered  818 non-null    object
#  5   fuel_type    815 non-null    object
# dtypes: int32(2), object(4)
# memory usage: 38.3+ KB

# %%
 car.kms_covered= car['kms_covered'].str.split(' ').str.get(0).str.replace(',','')

# %%
car= car[car['kms_covered'].str.isnumeric()]
car
# Out:
#                                        name   company  year   price  \
# 0                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 3          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 5                                 Ford Figo      Ford  2012  175000
# 6                               Hyundai Eon   Hyundai  2013  190000
# ..                                      ...       ...   ...     ...
# 882              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 884               Tata Indica V2 DLE BS III      Tata  2009  110000
# 885                    Toyota Corolla Altis    Toyota  2009  300000
# 887                     Tata Zest XM Diesel      Tata  2018  260000
# 888                      Mahindra Quanto C8  Mahindra  2013  390000
#
#     kms_covered fuel_type
# 0            40    Diesel
# 2         28000    Petrol
# 3         36000    Diesel
# 5         41000    Diesel
# ...

# %%
car.kms_covered = car['kms_covered'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 816 entries, 0 to 888
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         816 non-null    object
#  1   company      816 non-null    object
#  2   year         816 non-null    int32
#  3   price        816 non-null    int32
#  4   kms_covered  816 non-null    int32
#  5   fuel_type    815 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 35.1+ KB

# %%
car= car[~car['fuel_type'].isna()]

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 815 entries, 0 to 888
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         815 non-null    object
#  1   company      815 non-null    object
#  2   year         815 non-null    int32
#  3   price        815 non-null    int32
#  4   kms_covered  815 non-null    int32
#  5   fuel_type    815 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 35.0+ KB

# %%
car['name'] = car['name'].str.split(' ').str.slice(0,3).str.join(' ')
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_18888\96074993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['name'] = car['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car = car.reset_index(drop=True)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         815 non-null    object
#  1   company      815 non-null    object
#  2   year         815 non-null    int32
#  3   price        815 non-null    int32
#  4   kms_covered  815 non-null    int32
#  5   fuel_type    815 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 28.8+ KB

# %%
car.describe()
# Out:
#               year         price    kms_covered
# count   815.000000  8.150000e+02     815.000000
# mean   2012.451534  4.121246e+05   46277.096933
# std       4.000896  4.753339e+05   34318.459638
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.925000e+05   56879.000000
# max    2019.000000  8.500003e+06  400000.000000

# %%
car= car[car['price']<6e6].reset_index(drop=True)

# %%
car
# Out:
#                        name   company  year   price  kms_covered fuel_type
# 0       Mahindra Jeep CL550  Mahindra  2006  425000           40    Diesel
# 1         Hyundai Grand i10   Hyundai  2014  325000        28000    Petrol
# 2    Ford EcoSport Titanium      Ford  2014  575000        36000    Diesel
# 3                 Ford Figo      Ford  2012  175000        41000    Diesel
# 4               Hyundai Eon   Hyundai  2013  190000        25000    Petrol
# ..                      ...       ...   ...     ...          ...       ...
# 809      Maruti Suzuki Ritz    Maruti  2011  270000        50000    Petrol
# 810          Tata Indica V2      Tata  2009  110000        30000    Diesel
# 811    Toyota Corolla Altis    Toyota  2009  300000       132000    Petrol
# 812            Tata Zest XM      Tata  2018  260000        27000    Diesel
# 813      Mahindra Quanto C8  Mahindra  2013  390000        40000    Diesel
#
# [814 rows x 6 columns]

# %%
car.to_csv('clean_car1.csv')

# %% [markdown]
# ## Model

# %%
x = car.drop(columns='price')
y = car['price']

# %%
x
# Out:
#                        name   company  year  kms_covered fuel_type
# 0       Mahindra Jeep CL550  Mahindra  2006           40    Diesel
# 1         Hyundai Grand i10   Hyundai  2014        28000    Petrol
# 2    Ford EcoSport Titanium      Ford  2014        36000    Diesel
# 3                 Ford Figo      Ford  2012        41000    Diesel
# 4               Hyundai Eon   Hyundai  2013        25000    Petrol
# ..                      ...       ...   ...          ...       ...
# 809      Maruti Suzuki Ritz    Maruti  2011        50000    Petrol
# 810          Tata Indica V2      Tata  2009        30000    Diesel
# 811    Toyota Corolla Altis    Toyota  2009       132000    Petrol
# 812            Tata Zest XM      Tata  2018        27000    Diesel
# 813      Mahindra Quanto C8  Mahindra  2013        40000    Diesel
#
# [814 rows x 5 columns]

# %%
y
# Out:
# 0      425000
# 1      325000
# 2      575000
# 3      175000
# 4      190000
#         ...
# 809    270000
# 810    110000
# 811    300000
# 812    260000
# 813    390000
# Name: price, Length: 814, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder()
ohe.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#         'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#         'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#         'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#         'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#         'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#         'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#         'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#         'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...

# %%
column_trains = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                       remainder='passthrough')

# %%
model = LinearRegression()

# %%
pipe = make_pipeline(column_trains,model)
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y_pred = pipe.predict(x_test)

# %%
y_pred
# Out:
# array([ 400838.95571943, 1051299.33760204,  304093.52312905,
#         598486.16517533,  269871.63443882,  361202.62843997,
#         153200.43294539,  580173.76553309,  256329.50311306,
#         562331.16407475,  408683.26038999,  328704.54728282,
#         176313.18804346,  532381.03698974,  525802.69901516,
#         -32834.05595691,  465759.42969067,  248391.21176156,
#         161183.92526133,  384565.08936651,  169416.09522638,
#         421191.82215343,  366319.01675103,  180920.54490039,
#          57829.93610376,  155105.23463533,  713079.11984795,
#         450299.10408551,  360729.8486542 ,  532381.03698974,
#         280879.05371001,  204018.29249579,  619524.95189986,
#         137846.62353306,  383335.66302142,  392862.55616327,
#         411091.06116832,  726293.09867323,  333670.07825634,
#         361072.21016139,  194926.11741087,   72133.15510061,
#         498430.97668211,  114631.03528029,  257035.26756097,
# ...

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6835501331471412

# %%
scores = []
for i in range (1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
    model = LinearRegression()
    pipe = make_pipeline(column_trains,model)
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    print(r2_score(y_test,y_pred),i)
    scores.append(r2_score(y_test,y_pred))
# Out:
# 0.6789845996376324 0
# 0.6188878488384618 1
# 0.6602264866658625 2
# 0.6952893142875227 3
# 0.5563165458097534 4
# 0.5829930628157236 5
# 0.6035377256957926 6
# 0.6419404617756199 7
# 0.5504507474513975 8
# 0.47200655779175427 9
# 0.481993354992441 10
# 0.6558535927377289 11
# 0.7379177579971513 12
# 0.6706955141441364 13
# 0.7630012792615056 14
# 0.5837335616736208 15
# 0.6677729303509794 16
# 0.7519333397801256 17
# 0.6574674042257849 18
# 0.6187387383417469 19
# 0.6339349274589059 20
# 0.624333461328426 21
# 0.6901243740161822 22
# 0.5511881480972597 23
# 0.6028261122028894 24
# 0.4594849263394183 25
# 0.6839314697424315 26
# 0.6824603253371626 27
# 0.628231127362509 28
# 0.4345509681675126 29
# 0.7253569163499507 30
# 0.7354190508275958 31
# 0.5711830858765001 32
# 0.5998360010473285 33
# 0.6804927859827679 34
# 0.6408129802850586 35
# 0.5617620477009626 36
# 0.648200827130951 37
# 0.48630699175260883 38
# 0.6835902925375279 39
# 0.613907531912637 40
# 0.5827112577178177 41
# ...

# %%
np.argmax(scores)
# Out:
# 704

# %%
scores[np.argmax(scores)]
# Out:
# 0.8364125643435691

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift', 'Maruti',2019,100,'Petrol']], columns=['name','company','year','kms_covered','fuel_type']))
# Out:
# array([466264.25807873])

# %%
pipe.predict(pd.DataFrame([['Hyundai Eon', 'Ford',2012,41000,'Diesel']], columns=['name','company','year','kms_covered','fuel_type']))
# Out:
# array([280767.09962723])

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Ritz', 'Maruti',2011,500,'Petrol']], columns=['name','company','year','kms_covered','fuel_type']))
# Out:
# array([157553.05202581])

# %%
x
# Out:
#                        name   company  year  kms_covered fuel_type
# 0       Mahindra Jeep CL550  Mahindra  2006           40    Diesel
# 1         Hyundai Grand i10   Hyundai  2014        28000    Petrol
# 2    Ford EcoSport Titanium      Ford  2014        36000    Diesel
# 3                 Ford Figo      Ford  2012        41000    Diesel
# 4               Hyundai Eon   Hyundai  2013        25000    Petrol
# ..                      ...       ...   ...          ...       ...
# 809      Maruti Suzuki Ritz    Maruti  2011        50000    Petrol
# 810          Tata Indica V2      Tata  2009        30000    Diesel
# 811    Toyota Corolla Altis    Toyota  2009       132000    Petrol
# 812            Tata Zest XM      Tata  2018        27000    Diesel
# 813      Mahindra Quanto C8  Mahindra  2013        40000    Diesel
#
# [814 rows x 5 columns]
